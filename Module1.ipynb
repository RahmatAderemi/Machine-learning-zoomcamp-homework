# %% [markdown]
# # ASSIGNMENT
# ### Question 1: What's the version of Pandas that you installed?

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
df = pd.read_csv("laptops.csv", index_col= 0)
df
# Out:
#                                                          Status   Brand  \
# Laptop
# ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core ...          New    Asus
# Alurin Go Start Intel Celeron N4020/8GB/256GB S...          New  Alurin
# ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core ...          New    Asus
# MSI Katana GF66 12UC-082XES Intel Core i7-12700...          New     MSI
# HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB ...          New      HP
# ...                                                         ...     ...
# Razer Blade 17 FHD 360Hz Intel Core i7-11800H/1...  Refurbished   Razer
# Razer Blade 17 FHD 360Hz Intel Core i7-11800H/1...  Refurbished   Razer
# Razer Blade 17 FHD 360Hz Intel Core i7-11800H/3...  Refurbished   Razer
# Razer Book 13 Intel Evo Core i7-1165G7/16GB/1TB...  Refurbished   Razer
# Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/2...  Refurbished   Razer
#
#                                                          Model  \
# Laptop
# ...

# %% [markdown]
# ### Question 2: How many records are in the dataset?

# %%
len(df)
# Out:
# 2160

# %% [markdown]
# ### Question 3: How many laptop brands are presented in the dataset?

# %%
df.Brand.nunique()
# Out:
# 27

# %% [markdown]
# ### Question 4: How many columns in the dataset have missing values?

# %%
df.isnull().sum()
# Out:
# Status             0
# Brand              0
# Model              0
# CPU                0
# RAM                0
# Storage            0
# Storage type      42
# GPU             1371
# Screen             4
# Touch              0
# Final Price        0
# dtype: int64

# %% [markdown]
# ## Question 5: What's the maximum final price of Dell notebooks in the dataset?

# %%
df.groupby("Brand").count()
# Out:
#                   Status  Model  CPU  RAM  Storage  Storage type  GPU  Screen  \
# Brand
# Acer                 137    137  137  137      137           137   51     136
# Alurin                29     29   29   29       29            25    0      29
# Apple                116    116  116  116      116           105    9     116
# Asus                 415    415  415  415      415           409  168     415
# Deep Gaming            8      8    8    8        8             8    8       8
# Dell                  84     84   84   84       84            84    6      84
# Denver                 1      1    1    1        1             1    0       1
# Dynabook Toshiba      19     19   19   19       19            19    0      19
# Gigabyte              48     48   48   48       48            48   46      48
# HP                   368    368  368  368      368           361   87     367
# Innjoo                 6      6    6    6        6             6    0       6
# ...

# %%
dell= df[df["Brand"] == "Dell"]
dell
# Out:
#                                                          Status Brand  \
# Laptop
# Dell Vostro 3510 Intel Core i3-1115G4/8 GB/256G...          New  Dell
# Dell Vostro 3510 Intel Core i5-1135G7/8 GB/256G...          New  Dell
# Dell Vostro 3520 Intel Core i7-1255U/16GB/512GB...          New  Dell
# Dell Latitude 3520 Intel Core i5-1135G7/8GB/256...          New  Dell
# Dell Vostro 3510 Intel Core i5-1135G7/16 GB/512...          New  Dell
# ...                                                         ...   ...
# Dell Vostro 5301 Intel Core i5-1135G7/8GB/256GB...  Refurbished  Dell
# Dell Vostro 5301 Intel Core i5-1135G7/8GB/512GB...  Refurbished  Dell
# Dell Vostro 5502 Intel Core i5-1135G7/8GB/512GB...  Refurbished  Dell
# Dell XPS 13 9300 Intel Core i5-1035G1/8GB/512GB...  Refurbished  Dell
# Dell XPS 7390 Intel Core i7-10510U/16GB/512GB S...  Refurbished  Dell
#
#                                                        Model            CPU  \
# Laptop
# ...

# %%
dell["Final Price"].max()
# Out:
# np.float64(3936.0)

# %% [markdown]
# ### Q6. Median value of Screen

# %%
# Find the median value of Screen column in the dataset.
screen = df[["Screen"]]
print(screen.median())
# Next, calculate the most frequent value of the same Screen column.
freq = screen.mode()
print(freq)
# Out:
# Screen    15.6
# dtype: float64
#    Screen
# 0    15.6

# %%
# Use fillna method to fill the missing values in Screen column with the most frequent value from the previous step.
newscreen= screen.fillna(15.6)

# %%
newscreen.median()
# Out:
# Screen    15.6
# dtype: float64

# %% [markdown]
# ### Q7: Sum of weights

# %%
# Select all the "Innjoo" laptops from the datase
df.index
# Out:
# Index(['ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core i5-1235U/8GB/512GB SSD/15.6"',
#        'Alurin Go Start Intel Celeron N4020/8GB/256GB SSD/15.6"',
#        'ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core i3-1215U/8GB/256GB SSD/15.6"',
#        'MSI Katana GF66 12UC-082XES Intel Core i7-12700H/16GB/1TB SSD/RTX3050/15.6"',
#        'HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB SSD/15.6"',
#        'MSI Crosshair 17 C12VF-264XES Intel Core i7-12650H/32GB/1TB SSD/RTX 4060/17.3"',
#        'Lenovo Thinkpad E14 Gen 4 AMD Ryzen 5 5625U/8GB/256GB SSD/14"',
#        'ASUS VivoBook 15 F515JA-EJ2882W Intel Core i7-1065G7/8GB/512GB SSD/15.6"',
#        'Medion Akoya E15415 Intel Core i5-10210U/8GB/256GB SSD/15.6"',
#        'HP Victus 16-d1038ns Intel Core i7-12700H/16GB/512GB SSD/RTX 3050/16.1"',
#        ...
#        'Razer Blade 15 Advanced Model QHD Intel Core i7-11800H/32 GB/1TB SSD/RTX 3080/15.6"',
# ...

# %%
#Select all the "Innjoo" laptops from the datase
injoo = df[df.Brand == "Innjoo"]
injoo
# Out:
#                                                    Status   Brand Model  \
# Laptop
# InnJoo Voom Excellence Intel Celeron N4020/8GB/...    New  Innjoo  Voom
# InnJoo Voom Excellence Pro Intel Celeron N4020/...    New  Innjoo  Voom
# Innjoo Voom Intel Celeron N3350/4GB/64GB eMMC/1...    New  Innjoo  Voom
# Innjoo Voom Laptop Max Intel Celeron N3350/6GB/...    New  Innjoo  Voom
# Innjoo Voom Laptop Pro Intel Celeron N3350/6GB/...    New  Innjoo  Voom
# Innjoo Voom Pro Intel Celeron N3350/6GB/128GB e...    New  Innjoo  Voom
#
#                                                               CPU  RAM  \
# Laptop
# InnJoo Voom Excellence Intel Celeron N4020/8GB/...  Intel Celeron    8
# InnJoo Voom Excellence Pro Intel Celeron N4020/...  Intel Celeron    8
# Innjoo Voom Intel Celeron N3350/4GB/64GB eMMC/1...  Intel Celeron    4
# Innjoo Voom Laptop Max Intel Celeron N3350/6GB/...  Intel Celeron    6
# Innjoo Voom Laptop Pro Intel Celeron N3350/6GB/...  Intel Celeron    6
# ...

# %%
#Select only columns RAM, Storage, Screen.
newdf= injoo[["RAM", "Storage","Screen"]]
newdf
# Out:
#                                                     RAM  Storage  Screen
# Laptop
# InnJoo Voom Excellence Intel Celeron N4020/8GB/...    8      256    15.6
# InnJoo Voom Excellence Pro Intel Celeron N4020/...    8      512    15.6
# Innjoo Voom Intel Celeron N3350/4GB/64GB eMMC/1...    4       64    14.1
# Innjoo Voom Laptop Max Intel Celeron N3350/6GB/...    6       64    14.1
# Innjoo Voom Laptop Pro Intel Celeron N3350/6GB/...    6      128    14.1
# Innjoo Voom Pro Intel Celeron N3350/6GB/128GB e...    6      128    14.1

# %%
# Get the underlying NumPy array. Let's call it X.
X = newdf.values
X
# Out:
# array([[  8. , 256. ,  15.6],
#        [  8. , 512. ,  15.6],
#        [  4. ,  64. ,  14.1],
#        [  6. ,  64. ,  14.1],
#        [  6. , 128. ,  14.1],
#        [  6. , 128. ,  14.1]])

# %%
# Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result XTX.
Xt = x.T
Xt
# Out:
# array([[  8. ,   8. ,   4. ,   6. ,   6. ,   6. ],
#        [256. , 512. ,  64. ,  64. , 128. , 128. ],
#        [ 15.6,  15.6,  14.1,  14.1,  14.1,  14.1]])

# %%
import numpy as np
XtX =np.dot(Xt, X)
XtX
# Out:
# array([[2.52000e+02, 8.32000e+03, 5.59800e+02],
#        [8.32000e+03, 3.68640e+05, 1.73952e+04],
#        [5.59800e+02, 1.73952e+04, 1.28196e+03]])

# %%
#Compute the inverse of XTX.
inverse= np.linalg.inv(XtX)
inverse
# Out:
# array([[ 2.78025381e-01, -1.51791334e-03, -1.00809855e-01],
#        [-1.51791334e-03,  1.58286725e-05,  4.48052175e-04],
#        [-1.00809855e-01,  4.48052175e-04,  3.87214888e-02]])

# %%
#Create an array y with values [1100, 1300, 800, 900, 1000, 1100]
y= np.array([1100, 1300, 800, 900, 1000, 1100])
y
# Out:
# array([1100, 1300,  800,  900, 1000, 1100])

# %%
#Multiply the inverse of XTX with the transpose of X and then multiply the result by y. Call the result w.
mult = np.dot(inverse, Xt)
w= np.dot(mult, y)
w
# Out:
# array([45.58076606,  0.42783519, 45.29127938])

# %%
#What's the sum of all the elements of the result?
np.sum(w)
# Out:
# np.float64(91.2998806299555)
